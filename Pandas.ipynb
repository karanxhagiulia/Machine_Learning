# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Creazione di un df

# %%
np.random.seed(667)

mydata= np.random.randint(0,101,(4,3))
mydata
# Out:
# array([[ 85,  15,  89],
#        [100,   3,  90],
#        [  2,  64,   0],
#        [ 36,  99,  47]])

# %%
myindex=['A','B','C','D']

# %%
mycolumns = ['Gennaio', 'Febbraio','Marzo']

# %%
df = pd.DataFrame(data = mydata, index=myindex, columns=mycolumns)

# %%
df
# Out:
#    Gennaio  Febbraio  Marzo
# A       85        15     89
# B      100         3     90
# C        2        64      0
# D       36        99     47

# %% [markdown]
# #Len

# %%
len(df) #numero di righe
# Out:
# 4

# %% [markdown]
# #Info, dtype per sapere la tipologia di dato

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, A to D
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Gennaio   4 non-null      int64
#  1   Febbraio  4 non-null      int64
#  2   Marzo     4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
df.dtypes #le stringhe, solo una tipologia di dato
# Out:
# Gennaio     int64
# Febbraio    int64
# Marzo       int64
# dtype: object

# %%
df = pd.read_csv('tips_complete.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %% [markdown]
# #Transponi

# %%
df.describe().T #transpose (scambia righe con colonne)
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# #Shape, size, type

# %%
df.shape #numero
# Out:
# (244, 11)

# %%
df.size #numero di celle
# Out:
# 2684

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(df['total_bill']) #la tipologia di cosa è total_bill è una Series, ovvero una colonna
# Out:
# pandas.core.series.Series

# %%
df[['total_bill', 'tip']] #per due o più colonne doppie brackets

# %% [markdown]
# #Creazione di una nuova colonna

# %%
df['tip_percentage'] = 100* df['tip']/df['total_bill']
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percentage
# ...

# %%
df['price_per_person1'] = np.round(df['total_bill'] / df['size'], 3) #round arrotondo, dopo la virgola c'è 3 che è il numero di decimali

# %% [markdown]
# #Impostare un indice

# %%
df.set_index('Payment ID') #inplace=True in automatico, inserisco un indice, imposto Payment ID come indice ma mi fa solo vedere la preview, non lo imposta sul df

# %% [markdown]
# Se vado a vedere df avrò l'indice vecchio. Per impostare il nuovo indice ho due modi:
# *  sovrascrivo il nuovo df facendo df = df.set_index('Payment ID')
# * scrivo df.set_index('Payment ID', inplace=True)

# %%
df.set_index('Payment ID', inplace=True)

# %% [markdown]
# #Creare una copia del df

# %%
df1 = df.copy() #creo la copia del DF

# %% [markdown]
# #LOC/ILOC

# %% [markdown]
# *  iloc con i numeri/index
# *  loc con i valori/stringa

# %% [markdown]
# Questi due esempi sono uguali:

# %%
df.iloc[0] #mi fa vedere tutti i valori della prima riga
# Out:
# total_bill                        16.99
# tip                                1.01
# sex                              Female
# smoker                               No
# day                                 Sun
# time                             Dinner
# size                                  2
# price_per_person                  8.495
# Payer Name           Christy Cunningham
# CC Number              3560325168603410
# tip_percentage                 5.944673
# price_per_person1                 8.495
# Name: Sun2959, dtype: object

# %%
df.loc['Sun2959']
# Out:
# total_bill                        16.99
# tip                                1.01
# sex                              Female
# smoker                               No
# day                                 Sun
# time                             Dinner
# size                                  2
# price_per_person                  8.495
# Payer Name           Christy Cunningham
# CC Number              3560325168603410
# tip_percentage                 5.944673
# price_per_person1                 8.495
# Name: Sun2959, dtype: object

# %% [markdown]
# #Slicing

# %%
df.iloc[:4] #il 4 escluso ma iniziando da 0 sono le prime 4
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959             8.495000  Christy Cunningham  3560325168603410
# Sun4608             3.446667      Douglas Tucker  4478071379779230
# Sun4458             7.003333      Travis Walters  6011812112971322
# Sun5260            11.840000    Nathaniel Harris  4676137647685994
#
#             tip_percentage  price_per_person1
# Payment ID
# Sun2959           5.944673              8.495
# Sun4608          16.054159              3.447
# Sun4458          16.658734              7.003
# Sun5260          13.978041             11.840

# %%
df.loc[['Sun2959','Sun5260']]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                8.495  Christy Cunningham  3560325168603410
# Sun5260               11.840    Nathaniel Harris  4676137647685994
#
#             tip_percentage  price_per_person1
# Payment ID
# Sun2959           5.944673              8.495
# Sun5260          13.978041             11.840

# %% [markdown]
# #Droppare un elemento

# %% [markdown]
# *  Axis=1 è la **colonna**
# *  Axis=0 è la **riga**

# %%
df.drop('Sun2959', axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# Sun9679          25.29  4.71    Male     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person        Payer Name         CC Number  \
# Payment ID
# Sun4608             3.446667    Douglas Tucker  4478071379779230
# ...

# %%
#RICORDA di mettere df= sennò non lo sovrascrive
df = df.drop('Sun2959', axis=0)

# %% [markdown]
# #Append

# %%
first_row = df.loc['Sun4608']
first_row
# Out:
# total_bill                      10.34
# tip                              1.66
# sex                              Male
# smoker                             No
# day                               Sun
# time                           Dinner
# size                                3
# price_per_person             3.446667
# Payer Name             Douglas Tucker
# CC Number            4478071379779230
# tip_percentage              16.054159
# price_per_person1               3.447
# Name: Sun4608, dtype: object

# %%
df.append(first_row)

# %% [markdown]
# #Trasformo tipologia della serie in array

# %%
type(first_row)
# Out:
# pandas.core.series.Series

# %%
array_row = df.loc['Sun4608'].values #posso anche fare first_row.values
array_row
# Out:
# array([10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3, 3.4466666666666668,
#        'Douglas Tucker', 4478071379779230, 16.054158607350097, 3.447],
#       dtype=object)

# %% [markdown]
# #Groupby

# %%
df.groupby('class').count()

# %%
df1
# Out:
# labels                  0            1           2            3
# Alcohol count   59.000000    23.000000   57.000000    39.000000
#         mean    12.870000    13.860000   12.475088    13.459487
#         std      0.750051     0.366246    0.632430     0.663487
#         min     11.450000    13.160000   11.030000    11.960000
#         25%     12.330000    13.675000   12.080000    13.050000
# ...                   ...          ...         ...          ...
# Proline min    550.000000  1185.000000  278.000000   830.000000
#         25%    611.000000  1267.500000  380.000000   882.500000
#         50%    660.000000  1285.000000  450.000000  1015.000000
#         75%    712.000000  1412.500000  495.000000  1062.500000
#         max    795.000000  1680.000000  530.000000  1150.000000
#
# [104 rows x 4 columns]

# %%
labels_df[labels_df['labels']==0]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 4      13.24        2.59  2.87          21.0        118           2.80
# 20     14.06        1.63  2.28          16.0        126           3.00
# 21     12.93        3.80  2.65          18.6        102           2.41
# 39     14.22        3.99  2.51          13.2        128           3.00
# 40     13.56        1.71  2.31          16.2        117           3.15
# 43     13.24        3.98  2.29          17.5        103           2.64
# 60     12.33        1.10  2.28          16.0        101           2.05
# 62     13.67        1.25  1.92          18.0         94           2.10
# 65     12.37        1.21  2.56          18.1         98           2.42
# 68     13.34        0.94  2.36          17.0        110           2.53
# 69     12.21        1.19  1.75          16.8        151           1.85
# 78     12.33        0.99  1.95          14.8        136           1.90
# ...

# %%
labels_df[labels_df['labels']==0].describe()
# Out:
#          Alcohol  Malic_Acid        Ash  Ash_Alcanity   Magnesium  \
# count  59.000000   59.000000  59.000000     59.000000   59.000000
# mean   12.870000    2.697627   2.379322     20.240678   99.830508
# std     0.750051    1.246264   0.274703      2.714337   15.033471
# min    11.450000    0.940000   1.700000     13.200000   70.000000
# 25%    12.330000    1.650000   2.280000     18.500000   89.000000
# 50%    12.860000    2.580000   2.360000     20.000000   97.000000
# 75%    13.425000    3.645000   2.570000     22.000000  106.000000
# max    14.340000    5.650000   2.920000     26.000000  151.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count      59.000000   59.000000             59.000000        59.000000
# mean        2.027627    1.427288              0.404237         1.434915
# std         0.537428    0.868830              0.133819         0.627805
# min         1.150000    0.470000              0.140000         0.410000
# ...

# %%
labels[labels==-1] #per trovare dov'è il label nella colonna label con -1
# Out:
# 128   -1
# Name: labels, dtype: int64

# %%
(labels==-1).sum() #per vedere quante ce ne sono
# Out:
# 1

# %% [markdown]
# #Per vedere categorical e numerical features

# %%
categorical_features = [col for col in train_df.columns if train_df[col].dtype==object] #per trovare le features con object come tipo di dato nelle colonne

# %%
numerical_features = [col for col in train_df.columns if train_df[col].dtype!=object] #per le features numeriche

# %% [markdown]
# Prendi una colonna per ogni colonna nel mio train df se il tipo è oggetto

# %%
[col for col in train_df.columns if train_df[col].dtype==object]
# Out:
# ['Country', 'Status']

# %%
#oppure 
train_df[categorical_features]
# Out:
#                Country      Status
# 301             Israel  Developing
# 400             Greece  Developing
# 1224            Brazil  Developing
# 1113          Portugal   Developed
# 331            Eritrea  Developing
# ...                ...         ...
# 356            Croatia   Developed
# 960           Suriname  Developing
# 812           Maldives  Developing
# 132           Paraguay  Developing
# 885   Papua New Guinea  Developing
#
# [1047 rows x 2 columns]

# %% [markdown]
# #Valori nulli

# %% [markdown]
# ```
#
# df1 = df.fillna(df.mean()) #con la media
# df['numeri']=df['numeri'].fillna(0)
# df['numeri']=df['numeri'].fillna(df['numeri'].mean())
# df = df.dropna() #drop delle righe con valori nulli
#
# ```
#
#
# Replace:
# ```
#
# df = df.replace('simbolo da rimpiazzare', 0)
# ```
#
# Interpolate
#
# ```
#
# # To replace missing values with interpolated values, for example Age
# df['Age'] = df['Age'].interpolate()
# ```
